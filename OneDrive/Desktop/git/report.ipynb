# %% [markdown]
# <font face="times new roman" size="3" >
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" > Отчет по лабораторной работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«GIT»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" > Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" >       БИК2502 </p>
#   <p  align="right"> <font face="times new roman" size="3" > Меликова Тельназ Гамлет кызы</p>
#   <p  align="right"> <font face="times new roman" size="3" > Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" > Старший преподаватель ТиЗВ Егоров Дмитрий Аркадьевич</p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" > Москва, 2025 г. </p>
#
#   <hr>

# %% [markdown]
# <font face="times new roman" size="4">
# <center><b>Цель работы</b>
#
# <br>
#
# Получить практические знания и навыки работы с системой контроля версий Git и платформой GitHub для ведения индивидуальных и командных разработок, а также публикации веб-проектов.

# %% [markdown]
# <font face="times new roman" size="4"> <center><b>Процесс выполнения</b>

# %% [markdown]
# 1. Установка GIT.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Создать папку с проектом.

# %% [markdown]
# ![2025-11-12_21-23-28.png](data:image/png;base64,...)

# %% [markdown]
# 3. Открыть Git Bash.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Перейти в папку с проектом с помощью команды(на скрине) и инициализировать новый репозиторий. После выполнения команды появится скрытая папка .git, в которой будет храниться история версий проекта.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Добавления файла с отчетом(report.ipynb) в репозиторий

# %% [markdown]
# ![alt text](image-1.png)

# %% [markdown]
# 6. Выполнение коммита

# %% [markdown]
# ![alt text](image-2.png)

# %% [markdown]
# 7. Создание новой ветки и переход на нее

# %% [markdown]
# ![alt text](image-3.png)
